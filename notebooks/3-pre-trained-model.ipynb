# %%
from datasets import load_from_disk
import evaluate
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import TrainingArguments, Trainer, pipeline

# %%
ds = load_from_disk('/Users/kailiu/LLMProject/data/imdb_dataset')
train_ds = ds['train']
test_ds = ds['test']

# %%
# Initialize the tokenizer
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")


pipe = pipeline(
    "text-classification", 
    model="distilbert-base-uncased-finetuned-sst-2-english",
    tokenizer=tokenizer,
    device='mps',
    truncation=True,  # Truncate sequences longer than the model's max length
    padding=True      # Pad sequences to the model's max length
)

# %%
train_preds = pipe(train_ds['text'])
print(train_preds)
# Out:
# [{'label': 'POSITIVE', 'score': 0.7872871160507202}, {'label': 'NEGATIVE', 'score': 0.9991909861564636}, {'label': 'NEGATIVE', 'score': 0.998217761516571}, {'label': 'POSITIVE', 'score': 0.814460277557373}, {'label': 'NEGATIVE', 'score': 0.9993877410888672}, {'label': 'NEGATIVE', 'score': 0.9989563226699829}, {'label': 'NEGATIVE', 'score': 0.9994860887527466}, {'label': 'NEGATIVE', 'score': 0.9961752891540527}, {'label': 'NEGATIVE', 'score': 0.989343523979187}, {'label': 'NEGATIVE', 'score': 0.9909103512763977}, {'label': 'POSITIVE', 'score': 0.6470481753349304}, {'label': 'NEGATIVE', 'score': 0.9972400665283203}, {'label': 'NEGATIVE', 'score': 0.9925944209098816}, {'label': 'NEGATIVE', 'score': 0.996019184589386}, {'label': 'NEGATIVE', 'score': 0.9810841679573059}, {'label': 'NEGATIVE', 'score': 0.9997406601905823}, {'label': 'NEGATIVE', 'score': 0.9994814991950989}, {'label': 'NEGATIVE', 'score': 0.9997113347053528}, {'label': 'NEGATIVE', 'score': 0.9996881484985352}, {'label': 'NEGATIVE', 'score': 0.9996145963668823}, {'label': 'NEGATIVE', 'score': 0.9996248483657837}, {'label': 'NEGATIVE', 'score': 0.9970448613166809}, {'label': 'NEGATIVE', 'score': 0.9958439469337463}, {'label': 'NEGATIVE', 'score': 0.9926593899726868}, {'label': 'NEGATIVE', 'score': 0.9996039271354675}, {'label': 'NEGATIVE', 'score': 0.9995442032814026}, {'label': 'NEGATIVE', 'score': 0.9997547268867493}, {'label': 'NEGATIVE', 'score': 0.5901766419410706}, {'label': 'NEGATIVE', 'score': 0.999279797077179}, {'label': 'NEGATIVE', 'score': 0.9994862079620361}, {'label': 'NEGATIVE', 'score': 0.9997950196266174}, {'label': 'NEGATIVE', 'score': 0.9978421926498413}, {'label': 'POSITIVE', 'score': 0.984284520149231}, {'label': 'NEGATIVE', 'score': 0.9997926354408264}, {'label': 'NEGATIVE', 'score': 0.9996132254600525}, {'label': 'NEGATIVE', 'score': 0.9974316954612732}, {'label': 'NEGATIVE', 'score': 0.9997619986534119}, {'label': 'NEGATIVE', 'score': 0.9996505975723267}, {'label': 'NEGATIVE', 'score': 0.9992457628250122}, {'label': 'NEGATIVE', 'score': 0.5217057466506958}, {'label': 'NEGATIVE', 'score': 0.9989815354347229}, {'label': 'NEGATIVE', 'score': 0.9969856142997742}, {'label': 'NEGATIVE', 'score': 0.9992473125457764}, {'label': 'NEGATIVE', 'score': 0.9959748387336731}, {'label': 'NEGATIVE', 'score': 0.9965787529945374}, {'label': 'NEGATIVE', 'score': 0.9994447827339172}, {'label': 'NEGATIVE', 'score': 0.9994847774505615}, {'label': 'NEGATIVE', 'score': 0.9995902180671692}, {'label': 'NEGATIVE', 'score': 0.9997383952140808}, {'label': 'NEGATIVE', 'score': 0.9998045563697815}, {'label': 'NEGATIVE', 'score': 0.9866189360618591}, {'label': 'NEGATIVE', 'score': 0.9988574981689453}, {'label': 'NEGATIVE', 'score': 0.9989805817604065}, {'label': 'NEGATIVE', 'score': 0.9212755560874939}, {'label': 'NEGATIVE', 'score': 0.9980688691139221}, {'label': 'NEGATIVE', 'score': 0.997858464717865}, {'label': 'NEGATIVE', 'score': 0.9996023774147034}, {'label': 'NEGATIVE', 'score': 0.9958058595657349}, {'label': 'NEGATIVE', 'score': 0.9996621608734131}, {'label': 'NEGATIVE', 'score': 0.9997201561927795}, {'label': 'NEGATIVE', 'score': 0.9859010577201843}, {'label': 'POSITIVE', 'score': 0.9980944991111755}, {'label': 'NEGATIVE', 'score': 0.9997337460517883}, {'label': 'NEGATIVE', 'score': 0.9995737671852112}, {'label': 'NEGATIVE', 'score': 0.9838948845863342}, {'label': 'NEGATIVE', 'score': 0.9980065226554871}, {'label': 'NEGATIVE', 'score': 0.9991263747215271}, {'label': 'NEGATIVE', 'score': 0.9997594952583313}, {'label': 'NEGATIVE', 'score': 0.996753990650177}, {'label': 'NEGATIVE', 'score': 0.9900630116462708}, {'label': 'NEGATIVE', 'score': 0.9986382126808167}, {'label': 'NEGATIVE', 'score': 0.9978131055831909}, {'label': 'NEGATIVE', 'score': 0.999756395816803}, {'label': 'NEGATIVE', 'score': 0.993396520614624}, {'label': 'POSITIVE', 'score': 0.525830864906311}, {'label': 'NEGATIVE', 'score': 0.9993795156478882}, {'label': 'NEGATIVE', 'score': 0.9997922778129578}, {'labe ...

# %%
# convert the train_preds to a dataframe
import pandas as pd
train_preds_df = pd.DataFrame(train_preds)
print(train_preds_df)
# Out:
#           label     score
# 0      POSITIVE  0.787287
# 1      NEGATIVE  0.999191
# 2      NEGATIVE  0.998218
# 3      POSITIVE  0.814460
# 4      NEGATIVE  0.999388
# ...         ...       ...
# 24995  NEGATIVE  0.998632
# 24996  POSITIVE  0.994772
# 24997  POSITIVE  0.998151
# 24998  NEGATIVE  0.968497
# 24999  POSITIVE  0.999594
#
# [25000 rows x 2 columns]

# %%
# label the train_preds_df
train_preds_df['label'] = train_preds_df['label'].apply(lambda x: 1 if x == 'POSITIVE' else 0)
print(train_preds_df)
# Out:
#        label     score
# 0          1  0.787287
# 1          0  0.999191
# 2          0  0.998218
# 3          1  0.814460
# 4          0  0.999388
# ...      ...       ...
# 24995      0  0.998632
# 24996      1  0.994772
# 24997      1  0.998151
# 24998      0  0.968497
# 24999      1  0.999594
#
# [25000 rows x 2 columns]

# %%
# compute the accuracy
metric = evaluate.load("accuracy")
accuracy = metric.compute(predictions=train_preds_df['label'], references=train_ds['label'])
print(accuracy)
# Out:
# {'accuracy': 0.88852}

# %%
# test data for model
test_preds = pipe(test_ds['text'])
test_preds_df = pd.DataFrame(test_preds)
test_preds_df['label'] = test_preds_df['label'].apply(lambda x: 1 if x == 'POSITIVE' else 0)
accuracy = metric.compute(predictions=test_preds_df['label'], references=test_ds['label'])
print(accuracy)
# Out:
# {'accuracy': 0.89072}
